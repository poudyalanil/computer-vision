# %% [markdown]
# ### Corner Detection

# %% [markdown]
# - Harris Corner Detection
# - Shi-Tomashi corner Detection

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flat_chess = cv2.imread('flat-chess.jpg')
flat_chess = cv2.cvtColor(flat_chess,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(flat_chess)

# %%
gray_flat_chess = cv2.cvtColor(flat_chess,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(gray_flat_chess,cmap='gray')

# %%
real_chess = cv2.imread('real-chess-board.jpg')
real_chess = cv2.cvtColor(real_chess,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(real_chess)

# %%
gray_real_chess = cv2.cvtColor(real_chess,cv2.COLOR_RGB2GRAY)
plt.imshow(gray_real_chess,cmap='gray')

# %% [markdown]
# ### Harris Corner Detection Algorithm

# %%
gray = np.float32(gray_flat_chess)

# %%
dst = cv2.cornerHarris(src = gray,blockSize = 2, ksize = 3, k = 0.04)

# %%
dst = cv2.dilate(dst,None)

# %%
flat_chess[dst>0.01*dst.max()]= [0,0,0]

# %%
plt.imshow(flat_chess)

# %%
# for real chess board
gray_c = np.float32(gray_real_chess)

# %%
d = cv2.cornerHarris(src = gray_c,blockSize =2, ksize = 3, k = 0.04)

# %%
d = cv2.dilate(d,None)

# %%
real_chess[d>0.01*d.max()] = [255,0,0]

# %%
plt.imshow(real_chess)

# %% [markdown]
# ### Shi-Tomasi Algorithm

# %%
## getting all image data

real_chess = cv2.imread('real-chess-board.jpg')
real_chess = cv2.cvtColor(real_chess,cv2.COLOR_BGR2RGB)

flat_chess = cv2.imread('flat-chess.jpg')
flat_chess = cv2.cvtColor(flat_chess,cv2.COLOR_BGR2RGB)

gray_real_chess = cv2.cvtColor(real_chess,cv2.COLOR_RGB2GRAY)
gray_flat_chess = cv2.cvtColor(flat_chess,cv2.COLOR_RGB2GRAY)

# %%
flat_chess_corners = cv2.goodFeaturesToTrack(gray_flat_chess,55,0.01,10)

# %%
flat_chess_corners = np.int0(flat_chess_corners)

# %%
for i in flat_chess_corners:
    x,y = i.ravel()
    cv2.circle(flat_chess,(x,y),10,(255,0,0),-1)

# %%
plt.imshow(flat_chess)

# %%
# for real chess board

real_chess_corners = cv2.goodFeaturesToTrack(gray_real_chess,64,0.01,10)

# %%
real_chess_corners  = np.int0(real_chess_corners)

# %%
for c in real_chess_corners:
    x,y = c.ravel()
    cv2.circle(real_chess,(x,y),4,(255,0,0),-1)

# %%
plt.imshow(real_chess)
